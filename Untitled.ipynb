# %%
# %run createSampleImages
# Out:
# loading mnist training data
# converted  1 images
# converted  2 images
# converted  3 images
# converted  4 images
# converted  5 images
# converted  6 images
# converted  7 images
# converted  8 images
# converted  9 images
# converted  10 images
# size of trvecRed[x] 98
# expandOneByte [0, 0, 0, 0, 0, 0, 0, 0]
# expandOneByte [0, 0, 0, 0, 0, 0, 0, 0]
# expandOneByte [0, 0, 0, 0, 0, 0, 0, 0]
# expandOneByte [0, 0, 0, 0, 0, 0, 0, 0]
# expandOneByte [0, 0, 0, 0, 0, 0, 0, 0]
# expandOneByte [0, 0, 0, 0, 0, 0, 0, 0]
# expandOneByte [0, 0, 0, 0, 0, 0, 0, 0]
# expandOneByte [0, 0, 0, 0, 0, 0, 0, 0]
# expandOneByte [0, 0, 0, 0, 0, 0, 0, 0]
# expandOneByte [0, 0, 0, 0, 0, 0, 0, 0]
# expandOneByte [0, 0, 0, 0, 0, 0, 0, 0]
# expandOneByte [0, 0, 0, 0, 0, 0, 0, 0]
# expandOneByte [0, 0, 0, 0, 0, 0, 0, 0]
# expandOneByte [0, 0, 0, 0, 0, 0, 0, 0]
# expandOneByte [0, 0, 0, 0, 0, 0, 0, 0]
# expandOneByte [0, 0, 0, 0, 0, 0, 0, 0]
# expandOneByte [0, 0, 0, 0, 0, 0, 0, 0]
# ...
